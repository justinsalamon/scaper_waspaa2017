# %%
from scaper_waspaa2017.urban_sed_crnn import model as M
from imp import reload
# Out:
# Using TensorFlow backend.

# %%
m = M.build_crnn_onestep(n_freq_cnn=40, n_freq_rnn=10)
m.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 40, None, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 40, None, 96)      2496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40, None, 96)      384
# _________________________________________________________________
# activation_1 (Activation)    (None, 40, None, 96)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 40, None, 96)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 20, None, 96)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, None, 96)      230496
# ...

# %%
reload(M)
M.run_experiment_sedeval('exp002', epochs=1000, sequence_frames=128, sequence_hop=64, batch_size=64,
                         epoch_limit=None, sed_early_stopping=100, normalize_data=True,
                         fit_verbose=False, mel_bands=40, load_subset=None)
# Out:
# Module versions:
# keras version: 2.0.2
# tensorflow version: 1.0.1
# numpy version: 1.12.1
# sklearn version: 0.18.1
# label list (10):
# ['air_conditioner', 'car_horn', 'children_playing', 'dog_bark', 'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 'siren', 'street_music']
# Data shapes:
# (36000, 40, 128, 1) (36000, 128, 10)
# (6000, 40, 128, 1) (6000, 128, 10)
# (6000, 40, 128, 1) (6000, 128, 10)
#
# Building model...
#
# Fitting model...
# F1s: 0.0255, P1s: 0.1842, R1s: 0.0137, F100ms: 0.0178, P100ms: 0.1412, R100ms: 0.0095 | E1s: 1.0036, E100ms: 1.0126
# 0 Best val F1s: 0.0255 (IMPROVEMENT, saving)
#
# F1s: 0.0713, P1s: 0.1719, R1s: 0.0450, F100ms: 0.0493, P100ms: 0.1304, R100ms: 0.0304 | E1s: 1.0270, E100ms: 1.0545
# 1 Best val F1s: 0.0713 (IMPROVEMENT, saving)
#
# F1s: 0.0780, P1s: 0.1688, R1s: 0.0507, F100ms: 0.0551, P100ms: 0.1270, R100ms: 0.0352 | E1s: 1.0304, E100ms: 1.0657
# 2 Best val F1s: 0.0780 (IMPROVEMENT, saving)
#
# ...
