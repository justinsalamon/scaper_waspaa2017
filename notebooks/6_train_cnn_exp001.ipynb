# %%
from scaper_waspaa2017.urban_sed import model as M
from imp import reload
# Out:
# Using TensorFlow backend.

# %%
m = M.build_custom_cnn(n_freq_cnn=128)
m.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 128, 50, 1)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 124, 46, 64)       1664
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 23, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 62, 23, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 58, 19, 64)        102464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 29, 9, 64)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 29, 9, 64)         256
# ...

# %%
reload(M)
M.run_experiment_sedeval('exp001', epochs=1000, sequence_frames=50, sequence_hop=25, batch_size=64,
                         epoch_limit=None, sed_early_stopping=100, normalize_data=True,
                         fit_verbose=False, mel_bands=128, load_subset=None)
# Out:
# Module versions:
# keras version: 2.0.2
# tensorflow version: 1.0.1
# numpy version: 1.12.1
# sklearn version: 0.18.1
# label list (10):
# ['air_conditioner', 'car_horn', 'children_playing', 'dog_bark', 'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 'siren', 'street_music']
# Data shapes:
# (114000, 128, 50, 1) (114000, 10)
# (20000, 128, 50, 1) (20000, 10)
# (20000, 128, 50, 1) (20000, 10)
#
# Building model...
#
# Fitting model...
# F1s: 0.0352, P1s: 0.7741, R1s: 0.0180, F100ms: 0.0352, P100ms: 0.7741, R100ms: 0.0180 | E1s: 0.9820, E100ms: 0.9820
# 0 Best val F1s: 0.0352 (IMPROVEMENT, saving)
#
# F1s: 0.0794, P1s: 0.7918, R1s: 0.0418, F100ms: 0.0794, P100ms: 0.7918, R100ms: 0.0418 | E1s: 0.9583, E100ms: 0.9583
# 1 Best val F1s: 0.0794 (IMPROVEMENT, saving)
#
# F1s: 0.1356, P1s: 0.7849, R1s: 0.0742, F100ms: 0.1356, P100ms: 0.7849, R100ms: 0.0742 | E1s: 0.9259, E100ms: 0.9259
# 2 Best val F1s: 0.1356 (IMPROVEMENT, saving)
#
# ...
